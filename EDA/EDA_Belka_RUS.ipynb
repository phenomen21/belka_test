# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error,r2_score
import sklearn
from sklearn.model_selection import cross_val_score

# %%
# считываем данные
data = pd.read_excel('CityStarExport.xls',skiprows=3, index_col=None,header=1)
data.drop(columns=data.columns[0],inplace=True)
data.head()
# Out:
#                Дата                  Адрес Количество комнат   Цена, р.  \
# 0  07.06.2022 18:19          Суворова, 114     Однокомнатная  1 450 000
# 1  07.06.2022 18:19       Галиуллина, 49/2     Двухкомнатная  2 450 000
# 2  12.01.2022 16:19       Ленина пр-т, 112     Двухкомнатная  1 550 000
# 3  31.03.2022 18:19  50-летия Магнитки, 52     Трехкомнатная  3 050 000
# 4  23.05.2022 15:19         Советская, 149     Двухкомнатная  2 150 000
#
#   Планировка Этаж Общая площадь, м2 Жилая площадь, м2 Площадь кухни, м2  \
# 0        NaN  4/5             31,60             20,50              6,00
# 1        NaN  5/5             47,90              0,00              6,00
# 2        NaN  9/9             37,50             29,80              0,00
# 3        NaN  7/9             66,00             46,00              9,00
# 4        NaN  3/5             47,80              0,00              6,00
#
#                              Дополнительное описание  \
# 0  Продаётся  просторная и уютная однокомнатная к...
# 1  Просторная, светлая квартира ждёт своих новых ...
# 2  Удобный вариант двухкомнатной квартиры в центр...
# 3  В продаже большая 3-х комнатная квартира улучш...
# 4  В Правобережном районе  продам 2 комнатную  кв...
#
#                                             Контакты  \
# 0  Каримов Артём Раисович, Рио-Люкс  тел. +792269...
# 1  Гордейчук Евгения Юрьевна, Рио-Люкс  тел. +790...
# 2  Клочко Анна Валерьевна, Рио-Люкс  тел. +791280...
# 3  Клочко Анна Валерьевна, Рио-Люкс  тел. +791280...
# 4       Ержанова Моника, Рио-Люкс  тел. +79227329445
#
#                                       Адрес на сайте
# 0  http://magnitogorsk-citystar.ru/realty/prodazh...
# 1  http://magnitogorsk-citystar.ru/realty/prodazh...
# 2  http://magnitogorsk-citystar.ru/realty/prodazh...
# 3  http://magnitogorsk-citystar.ru/realty/prodazh...
# 4  http://magnitogorsk-citystar.ru/realty/prodazh...

# %%
# назначаем колонки
cols = ['date', 'address', 'rooms', 'price', 'planning', 'floor', 'area_total', 'area_living', 'area_kitchen', 'add_info',
        'contacts', 'url']
data.columns=cols

# %%
# как называется колонка с кол-вом комнат
data['rooms'].unique()
# Out:
# array(['Однокомнатная', 'Двухкомнатная', 'Трехкомнатная',
#        'Четырехкомнатная', 'Многокомнатная', nan], dtype=object)

# %%
# меняем текстовое кол-во комнат на числовое, 5 означает 5 и более

# %%
data.loc[(data['rooms']=='Однокомнатная'), 'rooms'] = 1
data.loc[(data['rooms']=='Двухкомнатная'), 'rooms'] = 2
data.loc[(data['rooms']=='Трехкомнатная'), 'rooms'] = 3
data.loc[(data['rooms']=='Четырехкомнатная'), 'rooms'] = 4
data.loc[(data['rooms']=='Многокомнатная'), 'rooms'] = 5

# %%
# посмотрим где NaN в количестве комнат
data.loc[(data['rooms'].isna()), :]
# Out:
#                   date                         address rooms       price  \
# 44    28.05.2022 18:01  ГСК Зеленый лог территория, 25   NaN   1 170 000
# 45    28.05.2022 18:01  ГСК Зеленый лог территория, 21   NaN   1 350 000
# 717   19.03.2022 04:42             ул Астраханская, 33   NaN   6 200 000
# 914   02.12.2021 05:28             ул Владимирская, 24   NaN   2 990 000
# 1277  02.03.2022 04:12                  Ворошилова, 13   NaN  10 000 000
#
#      planning  floor area_total area_living area_kitchen  \
# 44        NaN   6/10      24,00       12,00         6,00
# 45        NaN   1/10      24,20       12,00         6,00
# 717       NaN  12/17      33,00       20,00         5,00
# 914       NaN  -1/20      25,00       20,00        20,00
# 1277      NaN    4/4     123,50       40,00        24,00
#
#                                                add_info  \
# 44    1 комн. квартира по ул. Зеленый Лог. Общей пло...
# 45    1 комн. квартира по ул. Зеленый Лог. Общей пло...
# 717   Объект №34034 Продается упакованная квартира-с...
# 914   Объект №32348 Продается 1-комнатная квартира, ...
# 1277  Продается новая, просторная квартира-студия об...
#
#                                                contacts  \
# 44     Александр Николаевич, ЖИЛФОНД  тел. +79068510763
# 45     Александр Николаевич, ЖИЛФОНД  тел. +79068510763
# 717                Олег, Панорама  тел. (918) 494-06-00
# 914            Панорама, Панорама  тел. (800) 550-55-97
# 1277  ОН Перспектива 24 - Горячий Ключ, ОН Перспекти...
#
#                                                     url
# 44    http://magnitogorsk-citystar.ru/realty/prodazh...
# 45    http://magnitogorsk-citystar.ru/realty/prodazh...
# 717   http://magnitogorsk-citystar.ru/realty/prodazh...
# 914   http://magnitogorsk-citystar.ru/realty/prodazh...
# 1277  http://magnitogorsk-citystar.ru/realty/prodazh...

# %%
# это все однокомнатные, поэтому ставим 1
data.loc[(data['rooms'].isna()), 'rooms'] = 1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1322 non-null   object
#  1   address       1322 non-null   object
#  2   rooms         1322 non-null   object
#  3   price         1322 non-null   object
#  4   planning      586 non-null    object
#  5   floor         1322 non-null   object
#  6   area_total    1322 non-null   object
#  7   area_living   1322 non-null   object
#  8   area_kitchen  1322 non-null   object
#  9   add_info      1318 non-null   object
#  10  contacts      1322 non-null   object
#  11  url           1322 non-null   object
# dtypes: object(12)
# memory usage: 124.1+ KB

# %%
# обнаружилось, что продают квартиры в селах, удалю
data.fillna('', inplace=True)
data.drop(data[data['add_info'].str.contains('агапов', case=False)].index,inplace=True)

# %%
# в цене уберем пробелы
data['price'] = data['price'].str.replace(u'\xa0', '')

# %%
# в площади стоят запятые, будут проблемы с переводом во float
data['area_total'] = data['area_total'].str.replace(',', '.')
data['area_kitchen'] = data['area_kitchen'].str.replace(',', '.')
data['area_living'] = data['area_living'].str.replace(',', '.')
# тут будет сам этаж
data['fl'] = data['floor'].str.split('/',expand=True)[0].astype('int32')
data['fl_tot'] = data['floor'].str.split('/',expand=True)[1]
data.drop(data[data['fl_tot'] == ''].index, inplace=True)

# %%
# посмотрим распределение целевой переменной
data['price'] = data['price'].astype('int64')
data['price'].describe(percentiles=[.1,.25,.5,.75,.85,.9,.95,.99])
# Out:
# count    1.314000e+03
# mean     2.693844e+06
# std      1.423549e+06
# min      1.550000e+03
# 10%      1.550000e+06
# 25%      1.902500e+06
# 50%      2.500000e+06
# 75%      3.100000e+06
# 85%      3.590000e+06
# 90%      3.970000e+06
# 95%      4.735000e+06
# 99%      7.174000e+06
# max      2.729000e+07
# Name: price, dtype: float64

# %%
# есть несколько очень больших значений
data[data['price']>1e7]
# Out:
#                  date            address  rooms     price       planning  \
# 70   24.05.2022 13:19    Ленина пр-т, 69      1  19500000
# 161  27.02.2022 12:48  Ленина пр-т, 57/3      4  10500000     раздельная
# 433  20.03.2022 21:01   Карла Маркса, 56      2  27290000  нестандартная
# 975  09.06.2021 15:01     Набережная, 16      5  10700000  нестандартная
#
#     floor area_total area_living area_kitchen  \
# 70    5/5      34.00       19.00         8.00
# 161   2/7     140.00       70.00        18.00
# 433   5/5      41.00       30.00         6.00
# 975   2/5     196.00      120.00        25.00
#
#                                               add_info  \
# 70                     #объект в нашей базе №12389016#
# 161  Продается квартира элит класса, в самом центре...
# 433  ПОКУПАЯ ДАННУЮ КВАРТИРУ ВЫ ПОЛУЧАЕТЕ ПОМОЩЬ В ...
# 975  Пока объект на сайте, значит он в продаже.  О ...
#
#                                               contacts  \
# 70   Тугузова Алия Амиржановна, Рио-Люкс  тел. +790...
# 161  Александр  Сергеевич Конищев  тел. 8-909-74-72...
# 433  Лисицкая Вера Васильевна, Корпорация недвижимо...
# 975    Воронов Константин  тел. 890-8822-9922,43-02-39
#
#                                                    url  fl fl_tot
# 70   http://magnitogorsk-citystar.ru/realty/prodazh...   5      5
# 161  http://magnitogorsk-citystar.ru/realty/prodazh...   2      7
# 433  http://magnitogorsk-citystar.ru/realty/prodazh...   5      5
# 975  http://magnitogorsk-citystar.ru/realty/prodazh...   2      5

# %%
# видно, что несколько из них явно опечатки - маленькие квартиры с огромными ценами = ##70 и 433
data.loc[70,'price'] = data.loc[70,'price']/10
data.loc[433,'price'] = data.loc[433,'price']/10

# %%
# и похоже есть несколько очень маленьких значений, возможно тоже ошибки
data[data['price']<1e6]
# Out:
#                   date                           address  rooms   price  \
# 49    09.05.2022 17:07                   Малиновая, 10/9      2  238191
# 149   06.06.2022 14:19                          Труда, 2      3  650000
# 186   03.02.2022 16:19         Первомайский переулок, 13      2  850000
# 194   04.08.2021 14:23       спартаковский перулок, 10/1      1  300000
# 199   28.07.2021 18:41                      Калмыкова, 0      2  950000
# 263   04.08.2021 15:34  пос. Буранный, ул. Школьная , 66      2  930000
# 346   22.03.2022 04:37                   ул. Школьная, 3      2  999000
# 358   29.03.2022 23:04                  Карла Маркса, 64      1  930000
# 362   03.06.2022 12:55                 Ленина пр-т, 4-13      2  380000
# 401   02.06.2022 14:19                  Ленина пр-т, 112      1    1550
# 410   02.06.2022 13:19                   Ленина пр-т, 18      2    3900
# 418   02.06.2022 11:19                   Октябрьская, 14      2    2400
# 643   11.01.2022 16:21                 Ленина пр-т, 192а      1  950000
# 649   25.05.2022 22:23                  Карла Маркса, 60      5  650000
# 853   16.05.2022 18:19                  Карла Маркса, 64      1  990000
# 883   11.12.2019 15:40                   Клары Цеткин, 4      2  950000
# 884   05.07.2021 15:42                       Кирова, 131      2  850000
# 895   05.04.2022 04:20                   Молодежная, 19А      2  930000
# 1032  26.04.2022 16:34                  Советская, 115/1      3  500000
# 1120  11.01.2022 16:19                          Мира, 25      3  950000
# 1171  11.01.2022 16:19                        Новая, 1/5      2  480000
# 1295  27.01.2022 17:19                         Мира, 168      1  500000
#
#                planning floor area_total area_living area_kitchen  \
# 49                        1/1      48.60       30.00         8.00
# 149                       1/2      63.40        0.00         0.00
# 186                       1/2      50.30       34.00         8.00
# 194            хрущевка   2/5      34.50       19.00         6.40
# 199            хрущевка   1/2      44.00       27.00         6.00
# 263          раздельная   1/2      51.00       30.00         9.00
# 346                       2/2      43.10       32.00         6.00
# 358   гостиничного типа   2/5      18.30       13.00         2.00
# 362                       2/2      40.00       30.00         6.00
# 401                       9/9      38.00       19.00        10.00
# 410                       2/4      62.00       40.00        14.00
# 418                       3/5      43.00       27.00         6.00
# 643                       1/1      18.00       18.00        18.00
# 649       нестандартная   1/5      75.00       55.00         6.00
# 853                       5/5      18.30       12.90         0.00
# 883            хрущевка   2/2      41.00       20.00         6.00
# 884            хрущевка   1/2      40.50       21.00         6.00
# 895                       1/5      41.00       22.20         7.20
# 1032          брежневка   5/6      60.50       10.00         6.00
# 1120                      1/1      88.00       70.00         9.00
# 1171                      1/2      47.00       29.00         8.00
# 1295                      1/2      18.60       10.00         5.00
#
#                                                add_info  \
# 49    ПАО Сбербанк реализует имущество: \nОбъект (ID...
# 149   Продается теплая раздельная трехкомнатная квар...
# 186   Продам 2-ую квартиру 50 кв.м в с. Фершaмпенуaз...
# 194                      продам 1/3 долю квартиры.торг.
# 199   Дом за Молживом, правобережные очистные сооруж...
# 263   Продам 2х комнатную квартиру в пос. Буранное. ...
# 346   Продам уютную 2-х комнатную квартиру общей пло...
# 358   Однокомнатная квартира Гостиничного типа, на в...
# 362   Двухкомнатная квартира в пос. Южный Нагайбакск...
# 401   ОДНОКОМНАТНОЙ КВАРТИРЫ в центре города на ост....
# 410   квартира класса "ЛЮКС", в сердце Ленинского ра...
# 418   Состояние квартиры хорошее. Ремонт. Пластиковы...
# 643   Продам СТУДИЮ,  в новом строящемся поселке зак...
# 649   Сдам в аренду коммерческое помещение, 75 кв.м....
# 853   Продам однокомнатную квартиру Гостинку, 18,3 к...
# 883   !Продам квартиру в обычном состоянии. Плюсы эт...
# 884   !!Продам двухкомнатную квартиру в обычном сост...
# 895   ПPОДАЁТCЯ 2 К.КВ., ПО АДРEСУ село Шухободь, ул...
# 1032           Продам 1/5 долю в трехкомнатной квартире
# 1120  Земельном участок 8 соток. Рядом с домом на эт...
# 1171  Продам двухкомнатную квартиру улучшенной плани...
# 1295  Продам квартиру, в хорошем состоянии.В квартир...
#
#                                                contacts  \
# 49    Сотрудник ПАО Сбербанк, ПАО Сбербанк  тел. +78...
# 149   Ходжаева Наталья Дмитриевна, Рио-Люкс  тел. +7...
# 186   Климина Наталья Юрьевна, Рио-Люкс  тел. +79227...
# 194   Порпулова Оксана Аркадьевна, Магнитогорский го...
# 199       nadezdakrasnova1958@mail.ru  тел. 89512314452
# 263   Замушинская Ирина Рудольфовна  тел. 45-41-45; ...
# 346   Вадим Владимирович, Ипотечный сервис  тел. 796...
# 358                Акулова Ольга  тел. +7 912 316 78 09
# 362                         Екатерина  тел. 89514787109
# 401   Третьякова Диля Викторовна, Рио-Люкс  тел. +79...
# 410   Третьякова Диля Викторовна, Рио-Люкс  тел. +79...
# 418   Третьякова Диля Викторовна, Рио-Люкс  тел. +79...
# 643   Намоконов Сергей Анатольевич, Рио-Люкс  тел. +...
# 649     Воронов Константин  тел. 890-8822-9922,43-02-39
# 853   Устинова Елена Юрьевна, Рио-Люкс  тел. +795178...
# 883   Казанцева Юлия Александровна, Компания &quot;M...
# 884   Казанцева Юлия Александровна, Компания &quot;М...
# 895                 Григорий Голубев  тел. +79115050320
# 1032                Смолина Елена  тел. 8-912-797-02-31
# 1120  Ворожцова Елена Александровна, Рио-Люкс  тел. ...
# 1171  Яхин Данил Ихсанович, Рио-Люкс  тел. +79514596731
# 1295  Харитонов Никита Александрович, Рио-Люкс  тел....
#
#                                                     url  fl fl_tot
# 49    http://magnitogorsk-citystar.ru/realty/prodazh...   1      1
# 149   http://magnitogorsk-citystar.ru/realty/prodazh...   1      2
# 186   http://magnitogorsk-citystar.ru/realty/prodazh...   1      2
# 194   http://magnitogorsk-citystar.ru/realty/prodazh...   2      5
# 199   http://magnitogorsk-citystar.ru/realty/prodazh...   1      2
# 263   http://magnitogorsk-citystar.ru/realty/prodazh...   1      2
# 346   http://magnitogorsk-citystar.ru/realty/prodazh...   2      2
# 358   http://magnitogorsk-citystar.ru/realty/prodazh...   2      5
# 362   http://magnitogorsk-citystar.ru/realty/prodazh...   2      2
# 401   http://magnitogorsk-citystar.ru/realty/prodazh...   9      9
# 410   http://magnitogorsk-citystar.ru/realty/prodazh...   2      4
# 418   http://magnitogorsk-citystar.ru/realty/prodazh...   3      5
# 643   http://magnitogorsk-citystar.ru/realty/prodazh...   1      1
# 649   http://magnitogorsk-citystar.ru/realty/prodazh...   1      5
# 853   http://magnitogorsk-citystar.ru/realty/prodazh...   5      5
# 883   http://magnitogorsk-citystar.ru/realty/prodazh...   2      2
# 884   http://magnitogorsk-citystar.ru/realty/prodazh...   1      2
# 895   http://magnitogorsk-citystar.ru/realty/prodazh...   1      5
# 1032  http://magnitogorsk-citystar.ru/realty/prodazh...   5      6
# 1120  http://magnitogorsk-citystar.ru/realty/prodazh...   1      1
# 1171  http://magnitogorsk-citystar.ru/realty/prodazh...   1      2
# 1295  http://magnitogorsk-citystar.ru/realty/prodazh...   1      2

# %%
# три квартиры - цены в тысячах рублей, а не в рублях
data.loc[data['price']<4000, 'price'] *= 1000

# %%
#  есть доли, есть квартиры в селах, лучше все их удалить, дешевле 900 т.р.
data.drop(data[data['price']<9e5].index, inplace=True)

# %%
data['price'].describe(percentiles=[0.01,0.1,0.5,0.9,0.998])
# Out:
# count    1.304000e+03
# mean     2.684083e+06
# std      1.144952e+06
# min      9.300000e+05
# 1%       1.101960e+06
# 10%      1.560000e+06
# 50%      2.500000e+06
# 90%      3.967000e+06
# 99.8%    9.697000e+06
# max      1.070000e+07
# Name: price, dtype: float64

# %%
# поработаем с площадями - может они влияют друг на друга
data['area_total'] = data['area_total'].astype('float')
data['area_kitchen'] = data['area_kitchen'].astype('float')
data['area_living'] = data['area_living'].astype('float')

# %%
data.loc[:,data.columns.str.contains('area')].describe()
# Out:
#         area_total  area_living  area_kitchen
# count  1304.000000  1304.000000   1304.000000
# mean     49.758252    28.328658      7.859233
# std      20.012300    17.335246      4.567046
# min       4.000000     0.000000      0.000000
# 25%      35.275000    18.000000      6.000000
# 50%      45.200000    29.000000      7.000000
# 75%      61.000000    39.000000      9.000000
# max     220.000000   150.000000     50.000000

# %%
# общая площадь 4м - так не бывает
data.drop(data[data['area_total']<10].index, inplace=True)

# %%
sns.heatmap(data.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# отсюда я вижу, что общая площадь и жилая площадь сильно коррелируют

# %%
# пробую оставить площадь кухни, для этого удалю везде, где площадь кухни сильно маленькая
data.drop(data[data['area_kitchen']<5].index,inplace=True)

# %%
# построю ещё зависимость цены от площади
sns.scatterplot(data=data,x='area_total',y='price')
# Out:
# <AxesSubplot:xlabel='area_total', ylabel='price'>

# %%
#некоторые очень большие площади стоят ну как-то мало. может там явные особенные случаи
data[data['area_total']>190]
# Out:
#                  date                 address  rooms     price       planning  \
# 504  11.01.2022 16:19  Ленина пр-т, 210 стр.А      5   4400000
# 629  11.01.2022 16:21       Ленина пр-т, 129А      5   5000000
# 975  09.06.2021 15:01          Набережная, 16      5  10700000  нестандартная
#
#     floor  area_total  area_living  area_kitchen  \
# 504   1/1       200.0        100.0          25.0
# 629   1/1       220.0        150.0          20.0
# 975   2/5       196.0        120.0          25.0
#
#                                               add_info  \
# 504  Выгодное вложение в свой отдых в самом красиво...
# 629  Продам дачу площадью 230 кв метров, находится ...
# 975  Пока объект на сайте, значит он в продаже.  О ...
#
#                                               contacts  \
# 504  Клочко Анна Валерьевна, Рио-Люкс  тел. +791280...
# 629  Намоконов Сергей Анатольевич, Рио-Люкс  тел. +...
# 975    Воронов Константин  тел. 890-8822-9922,43-02-39
#
#                                                    url  fl fl_tot
# 504  http://magnitogorsk-citystar.ru/realty/prodazh...   1      1
# 629  http://magnitogorsk-citystar.ru/realty/prodazh...   1      1
# 975  http://magnitogorsk-citystar.ru/realty/prodazh...   2      5

# %%
# давайте их удалим - два дома в пригороде
data.drop(data[(data['area_total']>=200) & (data['price']<1e7)].index,inplace=True)

# %%
sns.scatterplot(data=data,x='area_total',y='price')
# есть ещё одна странная квартира, которая очень много стоит, но у неё маленькая площадь
# Out:
# <AxesSubplot:xlabel='area_total', ylabel='price'>

# %%
data[(data['price']>0.8e7) & (data['area_total']<40)]
# Out:
#                  date             address  rooms    price       planning  \
# 312  04.06.2022 18:29  Армавирская, 20Ак1      1  9500000  нестандартная
#
#     floor  area_total  area_living  area_kitchen  \
# 312  3/13        29.0         24.0          12.0
#
#                                               add_info  \
# 312  в Сочи в Дагомысе продаётся однокомнатная квар...
#
#                    contacts  \
# 312  Олег  тел. 89528575819
#
#                                                    url  fl fl_tot
# 312  http://magnitogorsk-citystar.ru/realty/prodazh...   3     13

# %%
# она вообще в Сочи, тоже надо удалить
data.drop(data.index[312], inplace=True)

# %%
# Переводим значения в числа
df = data.astype({'rooms':'int32',
                  'area_total':'float',
                  'area_kitchen':'float',
                  'area_living':'float',
                  'price':'float',
                  'fl_tot':'int32'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1191 entries, 0 to 1321
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1191 non-null   object
#  1   address       1191 non-null   object
#  2   rooms         1191 non-null   int32
#  3   price         1191 non-null   float64
#  4   planning      1191 non-null   object
#  5   floor         1191 non-null   object
#  6   area_total    1191 non-null   float64
#  7   area_living   1191 non-null   float64
#  8   area_kitchen  1191 non-null   float64
#  9   add_info      1191 non-null   object
#  10  contacts      1191 non-null   object
#  11  url           1191 non-null   object
#  12  fl            1191 non-null   int32
#  13  fl_tot        1191 non-null   int32
# dtypes: float64(4), int32(3), object(7)
# memory usage: 125.6+ KB

# %%
# хочу посмотреть, можно ли вытащить район
df['add_info'].str.contains('район').sum()
# Out:
# 477

# %%
# судя по всему, автоматически вытащить район не выходит, у нас слово "район" встречается в 500 описаниях из 1300

# %%
# на сайте youkarta.ru/cheljabinskaja-obl/magnitogorsk-74/ есть возможность вытащить все привязки улиц к районам
# это не на 100% точно, но наверное пойдет

# %%
# читаем скачанные файлы и делаем словари
streets_len = pd.read_excel('Magn_streets.xlsx', sheet_name=0,header=None)
streets_ord = pd.read_excel('Magn_streets.xlsx', sheet_name=1,header=None)
streets_prav = pd.read_excel('Magn_streets.xlsx', sheet_name=2,header=None)
# соединю в один словарь
streets = pd.concat([streets_len[0], streets_ord[0], streets_prav[0]]).str.lower()
districts = pd.concat([streets_len[1], streets_ord[1], streets_prav[1]]).str.lower()
dict_streets = dict(zip(streets, districts))

# %%
# вытащим улицу
# заодно заменим "проспект", "имени" и "площадь"
df['street'] = df['address'].str.strip().str.lower().str.split(',',expand=True)[0].str.replace('пр-т', 'проспект')
df['street'] = df['street'].str.replace('им ', 'имени') # не знаю, что это за магия но эта строка тут не работает
df['street'] = df['street'].str.replace('пл ', 'площадь ') # не знаю, что это за магия но эта строка тут не работает
# уберем всякие "ул", "улица" "ГСК" и "территория"
df['street'] = df['street'].str.replace('ул ', '') # не знаю, что это за магия но эта строка тут не работает
df['street'] = df['street'].str.replace('улица', '')
df['street'] = df['street'].str.replace('гск', '')
df['street'] = df['street'].str.replace('территория', '')
# удалим лишние пробелы, которые могли образоваться после удаления
df['street'] = df['street'].str.strip()
# удалим всякие символы, которые не являются символьными или пробелами (кавычки точки запятые и т.д.)
df['street'] = df['street'].str.replace('[^a-zA-Z0-9а-яА-Я \-]', '')
# удалим там, где улицы нет
df.drop(df[df['street']==''].index,inplace=True)
# удалю несколько ошибочных названий
df['street'] = df['street'].str.replace('перулок', 'переулок')
df['street'] = df['street'].str.replace('отябрьская', 'октябрьская')
df['street'] = df['street'].str.replace('50 лет', '50-летия')

# последнее подготовительное - удалим все строки, где улицы не совпадают с моим справочником
df.drop(df[~df['street'].isin(list(dict_streets.keys()))].index, inplace=True)

# и наконец добавлю район города
df['district'] = df['street'].apply(lambda x: dict_streets[x])
# Out:
# C:\Users\pheno\AppData\Local\Temp\ipykernel_8880\128435586.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['street'] = df['street'].str.replace('[^a-zA-Z0-9а-яА-Я \-]', '')

# %%
# удалим уже ненужные столбцы
df.drop(columns=['date','address','planning', 'add_info', 'contacts', 'url','street','area_living','floor'],
        inplace=True)

# %%
# у меня есть идея о том, что в разных районах цены могут быть разными
# давайте проверим

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1157 entries, 0 to 1321
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rooms         1157 non-null   int32
#  1   price         1157 non-null   float64
#  2   area_total    1157 non-null   float64
#  3   area_kitchen  1157 non-null   float64
#  4   fl            1157 non-null   int32
#  5   fl_tot        1157 non-null   int32
#  6   district      1157 non-null   object
# dtypes: float64(3), int32(3), object(1)
# memory usage: 58.8+ KB

# %%
# построю просто распределения цены в зависимости от района города
sns.displot(df, x='price', hue='district',kind='kde')
plt.xlim(0,1e7)
# Out:
# (0.0, 10000000.0)

# %%
# даже на таком простом графике я вижу, что район имеет значение (распределения разные), поэтому район в модели будет

# %%
sns.scatterplot(data=df, x='area_total', y='price',hue='district')
# Out:
# <AxesSubplot:xlabel='area_total', ylabel='price'>

# %%
# тут вроде все логично выглядит

# %%
# сделаем район числовым
districts = {'ленинский':0, 'орджоникидзевский':1, 'правобережный':2}
df['dist'] = df['district'].apply(lambda x: districts[x])
df.drop(columns=['district'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1157 entries, 0 to 1321
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rooms         1157 non-null   int32
#  1   price         1157 non-null   float64
#  2   area_total    1157 non-null   float64
#  3   area_kitchen  1157 non-null   float64
#  4   fl            1157 non-null   int32
#  5   fl_tot        1157 non-null   int32
#  6   dist          1157 non-null   int64
# dtypes: float64(3), int32(3), int64(1)
# memory usage: 91.0 KB

# %%
# тепловая карта признаков
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# как и ожидалось, кол-во комнат и площадь коррелируют с ценой сильно

# %%
# всего у меня 6 признаков (кол-во комнат, площадь общая, площадь кухни, этаж, число этажей, район)
# категориальные - район, этаж, кол-во этажей, числовые - число комнат, площади (общая и кухни)

# %%
#в итоге это мои данные
df.head(1)
# Out:
#    rooms      price  area_total  area_kitchen  fl  fl_tot  dist
# 0      1  1450000.0        31.6           6.0   4       5     2

# %%
# первое - линейная регрессия, с one-hot представлением, в лоб
y = df['price']
X = df.iloc[:, [0,2,3,4,5,6]]
cat_feats = ['dist','fl','fl_tot']
num_feats = ['area_total','area_kitchen','rooms']
pre_cat = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', num_feats),
        ("cat", OneHotEncoder(), cat_feats)]).fit(X)

X = pre_cat.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
lin_reg = LinearRegression()
lr_mod = lin_reg.fit(X_train,y_train)
print('Linear Regression')
print('r2:', r2_score(y_test,lr_mod.predict(X_test)))
print('cross_val:', cross_val_score(lr_mod,X,y,cv=5, scoring='r2').mean())
# Out:
# Linear Regression
# r2: 0.7920109972110118
# cross_val: 0.7362672851249782

# %%
# если разбивать трейн и тест без заданного random_state, то в тестовую и трейновую выборку попадают и точки, которые хорошо
# описываются моделью, и точки, которые плохо описываются, из-за этого при каждом запуске получается разный скор

# %%
# следующий catboost - он нативно умеет работать с категориальными признаками
y = df['price']
X = df.iloc[:, [0,2,3,4,5,6]]
cat_feats = ['dist','fl','fl_tot']
num_feats = ['area_total','area_kitchen','rooms']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

params = {'depth': 5, 'l2_leaf_reg': 3, 'learning_rate': 0.1, 'n_estimators':150}
cat_reg = CatBoostRegressor(silent=True, **params).fit(X_train,y_train, cat_features=cat_feats)

print('Catboost')
print('r2:', r2_score(y_test, cat_reg.predict(X_test)))
print('cross_val:', cross_val_score(cat_reg, X, y, cv=5).mean())
# Out:
# Catboost
# r2: 0.7394963886908982
# cross_val: 0.7146975931995607

# %%
# попробуем подобрать лучшие значения
from catboost import Pool
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
data_cat = Pool(X, y, cat_features=cat_feats)
params = {'learning_rate':[0.2,0.3,0.4],
          'max_depth':[3,4,5],
          'l2_leaf_reg': [6,7,8],
          'n_estimators':[200,300,400]}
cb_model = CatBoostRegressor(silent=True)
grid_found = cb_model.grid_search(params,data_cat,cv=5,plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# bestTest = 619340.9786
# bestIteration = 196
#
# 0:	loss: 619340.9786468	best: 619340.9786468 (0)	total: 3.23s	remaining: 4m 18s
#
# bestTest = 601325.0738
# bestIteration = 193
#
# 1:	loss: 601325.0737553	best: 601325.0737553 (1)	total: 6.83s	remaining: 4m 30s
#
# bestTest = 596576.2893
# bestIteration = 132
#
# 2:	loss: 596576.2892947	best: 596576.2892947 (2)	total: 9.89s	remaining: 4m 17s
#
# bestTest = 619832.8834
# bestIteration = 167
#
# 3:	loss: 619832.8834420	best: 596576.2892947 (2)	total: 14s	remaining: 4m 29s
#
# bestTest = 603819.9547
# bestIteration = 166
#
# 4:	loss: 603819.9547454	best: 596576.2892947 (2)	total: 18.2s	remaining: 4m 37s
#
# bestTest = 579668.6817
# bestIteration = 199
#
# 5:	loss: 579668.6817383	best: 579668.6817383 (5)	total: 22.2s	remaining: 4m 37s
#
# bestTest = 604637.2449
# bestIteration = 187
#
# 6:	loss: 604637.2449024	best: 579668.6817383 (5)	total: 26s	remaining: 4m 34s
#
# bestTest = 586332.6361
# bestIteration = 190
#
# 7:	loss: 586332.6360534	best: 579668.6817383 (5)	total: 29.7s	remaining: 4m 31s
#
# bestTest = 607502.2057
# bestIteration = 55
#
# 8:	loss: 607502.2057423	best: 579668.6817383 (5)	total: 33.3s	remaining: 4m 26s
#
# bestTest = 616761.4722
# bestIteration = 222
#
# 9:	loss: 616761.4722162	best: 579668.6817383 (5)	total: 38.6s	remaining: 4m 34s
#
# bestTest = 599910.1678
# bestIteration = 256
#
# 10:	loss: 599910.1677620	best: 579668.6817383 (5)	total: 43.7s	remaining: 4m 38s
#
# bestTest = 586490.1219
# bestIteration = 289
#
# 11:	loss: 586490.1219011	best: 579668.6817383 (5)	total: 48.8s	remaining: 4m 40s
#
# bestTest = 612722.022
# bestIteration = 298
#
# 12:	loss: 612722.0219959	best: 579668.6817383 (5)	total: 53.9s	remaining: 4m 41s
#
# bestTest = 592206.1403
# bestIteration = 289
#
# 13:	loss: 592206.1402511	best: 579668.6817383 (5)	total: 59.1s	remaining: 4m 43s
#
# bestTest = 574469.3169
# bestIteration = 298
#
# 14:	loss: 574469.3169373	best: 574469.3169373 (14)	total: 1m 4s	remaining: 4m 44s
#
# bestTest = 596633.8109
# bestIteration = 298
#
# 15:	loss: 596633.8109480	best: 574469.3169373 (14)	total: 1m 11s	remaining: 4m 51s
#
# bestTest = 583898.8843
# bestIteration = 237
#
# 16:	loss: 583898.8842746	best: 574469.3169373 (14)	total: 1m 18s	remaining: 4m 56s
#
# bestTest = 604938.8401
# bestIteration = 288
#
# 17:	loss: 604938.8401330	best: 574469.3169373 (14)	total: 1m 24s	remaining: 4m 57s
#
# bestTest = 612233.9829
# bestIteration = 396
#
# 18:	loss: 612233.9828647	best: 574469.3169373 (14)	total: 1m 33s	remaining: 5m 4s
#
# bestTest = 593756.6458
# bestIteration = 384
#
# 19:	loss: 593756.6458332	best: 574469.3169373 (14)	total: 1m 41s	remaining: 5m 8s
#
# bestTest = 580263.4221
# bestIteration = 377
#
# 20:	loss: 580263.4221433	best: 574469.3169373 (14)	total: 1m 49s	remaining: 5m 11s
#
# bestTest = 605574.8124
# bestIteration = 399
#
# 21:	loss: 605574.8123703	best: 574469.3169373 (14)	total: 1m 57s	remaining: 5m 14s
#
# bestTest = 591058.7717
# bestIteration = 362
#
# 22:	loss: 591058.7717218	best: 574469.3169373 (14)	total: 2m 6s	remaining: 5m 17s
#
# bestTest = 568002.8985
# bestIteration = 376
#
# 23:	loss: 568002.8985321	best: 568002.8985321 (23)	total: 2m 13s	remaining: 5m 16s
#
# bestTest = 590975.5245
# bestIteration = 373
#
# 24:	loss: 590975.5245102	best: 568002.8985321 (23)	total: 2m 21s	remaining: 5m 16s
#
# bestTest = 583898.8843
# bestIteration = 237
#
# 25:	loss: 583898.8842746	best: 568002.8985321 (23)	total: 2m 29s	remaining: 5m 17s
#
# bestTest = 598787.0327
# bestIteration = 387
#
# 26:	loss: 598787.0326722	best: 568002.8985321 (23)	total: 2m 37s	remaining: 5m 15s
#
# bestTest = 611414.6983
# bestIteration = 135
#
# 27:	loss: 611414.6982578	best: 568002.8985321 (23)	total: 2m 44s	remaining: 5m 11s
#
# bestTest = 594863.4919
# bestIteration = 197
#
# 28:	loss: 594863.4919430	best: 568002.8985321 (23)	total: 2m 51s	remaining: 5m 7s
#
# bestTest = 602832.5307
# bestIteration = 199
#
# 29:	loss: 602832.5307020	best: 568002.8985321 (23)	total: 2m 57s	remaining: 5m 2s
#
# bestTest = 603360.7701
# bestIteration = 178
#
# 30:	loss: 603360.7700833	best: 568002.8985321 (23)	total: 3m 3s	remaining: 4m 55s
#
# bestTest = 587595.9323
# bestIteration = 185
#
# 31:	loss: 587595.9322594	best: 568002.8985321 (23)	total: 3m 8s	remaining: 4m 49s
#
# bestTest = 592456.4306
# bestIteration = 153
#
# 32:	loss: 592456.4305753	best: 568002.8985321 (23)	total: 3m 13s	remaining: 4m 42s
#
# bestTest = 612266.0511
# bestIteration = 194
#
# 33:	loss: 612266.0511401	best: 568002.8985321 (23)	total: 3m 19s	remaining: 4m 35s
#
# bestTest = 584036.7999
# bestIteration = 164
#
# 34:	loss: 584036.7999486	best: 568002.8985321 (23)	total: 3m 24s	remaining: 4m 28s
#
# bestTest = 614592.3036
# bestIteration = 199
#
# 35:	loss: 614592.3036045	best: 568002.8985321 (23)	total: 3m 28s	remaining: 4m 21s
#
# bestTest = 601787.305
# bestIteration = 299
#
# 36:	loss: 601787.3050497	best: 568002.8985321 (23)	total: 3m 36s	remaining: 4m 17s
#
# bestTest = 590315.679
# bestIteration = 216
#
# 37:	loss: 590315.6790022	best: 568002.8985321 (23)	total: 3m 44s	remaining: 4m 13s
#
# bestTest = 592060.6022
# bestIteration = 296
#
# 38:	loss: 592060.6021757	best: 568002.8985321 (23)	total: 3m 51s	remaining: 4m 8s
#
# bestTest = 595403.2984
# bestIteration = 289
#
# 39:	loss: 595403.2984261	best: 568002.8985321 (23)	total: 3m 58s	remaining: 4m 4s
#
# bestTest = 582405.2486
# bestIteration = 250
#
# 40:	loss: 582405.2486422	best: 568002.8985321 (23)	total: 4m 5s	remaining: 3m 59s
#
# bestTest = 592044.3843
# bestIteration = 294
#
# 41:	loss: 592044.3842665	best: 568002.8985321 (23)	total: 4m 13s	remaining: 3m 55s
#
# bestTest = 604375.9947
# bestIteration = 271
#
# 42:	loss: 604375.9947125	best: 568002.8985321 (23)	total: 4m 21s	remaining: 3m 51s
#
# bestTest = 580748.1602
# bestIteration = 297
#
# 43:	loss: 580748.1601701	best: 568002.8985321 (23)	total: 4m 30s	remaining: 3m 47s
#
# bestTest = 606302.4481
# bestIteration = 297
#
# 44:	loss: 606302.4481323	best: 568002.8985321 (23)	total: 4m 39s	remaining: 3m 43s
#
# bestTest = 593484.5157
# bestIteration = 399
#
# 45:	loss: 593484.5156881	best: 568002.8985321 (23)	total: 4m 50s	remaining: 3m 40s
#
# bestTest = 590315.679
# bestIteration = 216
#
# 46:	loss: 590315.6790022	best: 568002.8985321 (23)	total: 5m 1s	remaining: 3m 37s
#
# bestTest = 588958.7881
# bestIteration = 391
#
# 47:	loss: 588958.7880666	best: 568002.8985321 (23)	total: 5m 11s	remaining: 3m 33s
#
# bestTest = 585228.1943
# bestIteration = 396
#
# 48:	loss: 585228.1942741	best: 568002.8985321 (23)	total: 5m 21s	remaining: 3m 29s
#
# bestTest = 582405.2486
# bestIteration = 250
#
# 49:	loss: 582405.2486422	best: 568002.8985321 (23)	total: 5m 31s	remaining: 3m 25s
#
# bestTest = 589309.343
# bestIteration = 352
#
# 50:	loss: 589309.3430153	best: 568002.8985321 (23)	total: 5m 40s	remaining: 3m 20s
#
# bestTest = 602698.0306
# bestIteration = 399
#
# 51:	loss: 602698.0305843	best: 568002.8985321 (23)	total: 5m 51s	remaining: 3m 15s
#
# bestTest = 580099.748
# bestIteration = 327
#
# 52:	loss: 580099.7479581	best: 568002.8985321 (23)	total: 6m 1s	remaining: 3m 10s
#
# bestTest = 601748.7591
# bestIteration = 378
#
# 53:	loss: 601748.7590699	best: 568002.8985321 (23)	total: 6m 13s	remaining: 3m 6s
#
# bestTest = 619445.7709
# bestIteration = 198
#
# 54:	loss: 619445.7708764	best: 568002.8985321 (23)	total: 6m 21s	remaining: 3m
#
# bestTest = 583270.2224
# bestIteration = 192
#
# 55:	loss: 583270.2223643	best: 568002.8985321 (23)	total: 6m 27s	remaining: 2m 53s
#
# bestTest = 602165.1766
# bestIteration = 199
#
# 56:	loss: 602165.1765719	best: 568002.8985321 (23)	total: 6m 34s	remaining: 2m 45s
#
# bestTest = 609748.438
# bestIteration = 199
#
# 57:	loss: 609748.4379546	best: 568002.8985321 (23)	total: 6m 41s	remaining: 2m 39s
#
# bestTest = 599379.5212
# bestIteration = 125
#
# 58:	loss: 599379.5212086	best: 568002.8985321 (23)	total: 6m 47s	remaining: 2m 32s
#
# bestTest = 601511.4928
# bestIteration = 138
#
# 59:	loss: 601511.4927976	best: 568002.8985321 (23)	total: 6m 54s	remaining: 2m 25s
#
# bestTest = 604904.0006
# bestIteration = 199
#
# 60:	loss: 604904.0006344	best: 568002.8985321 (23)	total: 7m 1s	remaining: 2m 18s
#
# bestTest = 604573.0257
# bestIteration = 193
#
# 61:	loss: 604573.0256880	best: 568002.8985321 (23)	total: 7m 8s	remaining: 2m 11s
#
# bestTest = 568887.0083
# bestIteration = 129
#
# 62:	loss: 568887.0083049	best: 568002.8985321 (23)	total: 7m 14s	remaining: 2m 4s
#
# bestTest = 606949.7793
# bestIteration = 294
#
# 63:	loss: 606949.7792889	best: 568002.8985321 (23)	total: 7m 24s	remaining: 1m 58s
#
# bestTest = 579886.9086
# bestIteration = 257
#
# 64:	loss: 579886.9086332	best: 568002.8985321 (23)	total: 7m 35s	remaining: 1m 52s
# bestTest = 592068.7546
# bestIteration = 268
#
# 65:	loss: 592068.7546023	best: 568002.8985321 (23)	total: 7m 45s	remaining: 1m 45s
#
# bestTest = 606355.232
# bestIteration = 296
#
# 66:	loss: 606355.2319998	best: 568002.8985321 (23)	total: 7m 55s	remaining: 1m 39s
#
# bestTest = 599379.5212
# bestIteration = 125
#
# 67:	loss: 599379.5212086	best: 568002.8985321 (23)	total: 8m 3s	remaining: 1m 32s
#
# bestTest = 601511.4928
# bestIteration = 138
#
# 68:	loss: 601511.4927976	best: 568002.8985321 (23)	total: 8m 13s	remaining: 1m 25s
#
# bestTest = 596862.3953
# bestIteration = 282
#
# 69:	loss: 596862.3952824	best: 568002.8985321 (23)	total: 8m 23s	remaining: 1m 19s
#
# bestTest = 597504.6835
# bestIteration = 252
#
# 70:	loss: 597504.6835446	best: 568002.8985321 (23)	total: 8m 32s	remaining: 1m 12s
#
# bestTest = 568887.0083
# bestIteration = 129
#
# 71:	loss: 568887.0083049	best: 568002.8985321 (23)	total: 8m 43s	remaining: 1m 5s
#
# bestTest = 602497.142
# bestIteration = 362
#
# 72:	loss: 602497.1419857	best: 568002.8985321 (23)	total: 8m 56s	remaining: 58.8s
#
# bestTest = 579178.9438
# bestIteration = 301
#
# 73:	loss: 579178.9437658	best: 568002.8985321 (23)	total: 9m 10s	remaining: 52.1s
#
# bestTest = 592068.7546
# bestIteration = 268
#
# 74:	loss: 592068.7546023	best: 568002.8985321 (23)	total: 9m 26s	remaining: 45.3s
#
# bestTest = 601457.0532
# bestIteration = 399
#
# 75:	loss: 601457.0532362	best: 568002.8985321 (23)	total: 9m 39s	remaining: 38.1s
#
# bestTest = 597826.3421
# bestIteration = 373
#
# 76:	loss: 597826.3421220	best: 568002.8985321 (23)	total: 9m 53s	remaining: 30.8s
#
# bestTest = 601511.4928
# bestIteration = 138
#
# 77:	loss: 601511.4927976	best: 568002.8985321 (23)	total: 10m 6s	remaining: 23.3s
#
# bestTest = 591042.2266
# bestIteration = 399
#
# 78:	loss: 591042.2266116	best: 568002.8985321 (23)	total: 10m 19s	remaining: 15.7s
#
# bestTest = 594674.5164
# bestIteration = 380
#
# 79:	loss: 594674.5164388	best: 568002.8985321 (23)	total: 10m 33s	remaining: 7.91s
#
# bestTest = 568887.0083
# bestIteration = 129
#
# 80:	loss: 568887.0083049	best: 568002.8985321 (23)	total: 10m 45s	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
#
# bestTest = 574359.4665
# bestIteration = 83
#
# Training on fold [1/5]
#
# bestTest = 591636.9097
# bestIteration = 97
#
# Training on fold [2/5]
#
# bestTest = 585705.4298
# bestIteration = 40
#
# Training on fold [3/5]
#
# bestTest = 596311.6522
# bestIteration = 57
#
# Training on fold [4/5]
#
# bestTest = 612724.4506
# bestIteration = 109

# %%
print(params)
print(grid_found['params'])
# Out:
# {'learning_rate': [0.2, 0.3, 0.4], 'depth': [3, 4, 5], 'l2_leaf_reg': [6, 7, 8], 'iterations': [200, 300, 400]}
# {'depth': 3, 'l2_leaf_reg': 7, 'iterations': 400, 'learning_rate': 0.4}

# %%
r2_score(y_test,cb_model.predict(X_test))
# Out:
# 0.8278031628753153

# %%
# catboost все время пытается переобучиться, подбирает минимальную глубину дерева и максимальное число деревьев, так себе

# %%
# попробую XGBoost, для этого тоже нужно сделать one-hot
import xgboost as xgb
y = df['price']
X = df.iloc[:, [0,2,3,4,5,6]]
cat_feats = ['dist','fl','fl_tot']
num_feats = ['area_total','area_kitchen','rooms']
pre_cat = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', num_feats),
        ("cat", OneHotEncoder(), cat_feats)]).fit(X)

X = pre_cat.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
params = {'n_estimators':150, 'max_depth':5, 'learning_rate':0.05}
xgb_model = xgb.XGBRegressor(**params).fit(X_train,y_train)
print('XGBoost')
print('r2:', xgb_model.score(X_test,y_test))
print('cross_val:', cross_val_score(xgb_model, X,y, cv=5).mean())
# Out:
# XGBoost
# r2: 0.7835110594961439
# cross_val: 0.7152184230971323

# %%
# поищем с помощью grid-search 
parameters = {
    'max_depth': range (3, 10, 2),
    'n_estimators': range(50, 300, 50),
    'learning_rate': [0.01, 0.05, 0.1]
}
grid_search = GridSearchCV(
    estimator=xgb.XGBRegressor(),
    param_grid=parameters,
    scoring = 'r2',
    n_jobs = -1,
    cv = 5,
    verbose=True
)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, predictor=None,
#                                     random_state=None, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': range(3, 10, 2),
#                          'n_estimators': range(50, 200, 50)},
#              scoring='r2', verbose=True)

# %%
grid_search.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=5, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=150, n_jobs=16,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
grid_search.best_score_
# Out:
# 0.7206721631707891

# %%
# буду всё-таки использовать xgboost, но перед его использованием обучу его на всём датасете, чтобы получить больше информации
y = df['price']
X = df.iloc[:, [0,2,3,4,5,6]]
cat_feats = [5,3,4]
num_feats = [1,2,0]
pre_cat = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', num_feats),
        ("cat", OneHotEncoder(), cat_feats)]).fit(X)

X_transf = pre_cat.transform(X)

params = {'n_estimators':150, 'max_depth':5, 'learning_rate':0.05}
xgb_model = xgb.XGBRegressor(**params).fit(X_transf,y)
xgb_model.score(X_transf, y)
# Out:
# 0.9104395106257723

# %%
# естесственно, свой датасет он запоминает неплохо

# %%
# сохраню трансформер и модель
import pickle
with open('col_transf.pkl', 'wb') as ct:
    pickle.dump(pre_cat, ct)

xgb_model.save_model('xgb_trained')
